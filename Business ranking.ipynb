# %% [markdown]
# # Import libralies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
uri = 'D:\The way to data scientist\Practise/Future50.csv'
df = pd.read_csv(uri)
df.head(5)
# Out:
#    Rank   Restaurant                  Location  Sales YOY_Sales  Units  \
# 0     1   Evergreens            Seattle, Wash.     24    130.5%     26
# 1     2  Clean Juice           Charlotte, N.C.     44    121.9%    105
# 2     3     Slapfish  Huntington Beach, Calif.     21     81.0%     21
# 3     4   Clean Eatz          Wilmington, N.C.     25     79.7%     46
# 4     5    Pokeworks            Irvine, Calif.     49     77.1%     50
#
#   YOY_Units  Unit_Volume Franchising
# 0    116.7%         1150          No
# 1     94.4%          560         Yes
# 2     90.9%         1370         Yes
# 3     58.6%          685         Yes
# 4     56.3%         1210         Yes

# %%
print(df.shape)
print(df.size)
print(df.info())
print(df.dtypes)
print(df.isnull())
# Out:
# (50, 9)
# 450
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         50 non-null     int64
#  1   Restaurant   50 non-null     object
#  2   Location     50 non-null     object
#  3   Sales        50 non-null     int64
#  4   YOY_Sales    50 non-null     object
#  5   Units        50 non-null     int64
#  6   YOY_Units    50 non-null     object
#  7   Unit_Volume  50 non-null     int64
#  8   Franchising  50 non-null     object
# dtypes: int64(4), object(5)
# memory usage: 3.6+ KB
# None
# Rank            int64
# Restaurant     object
# Location       object
# Sales           int64
# YOY_Sales      object
# Units           int64
# YOY_Units      object
# Unit_Volume     int64
# Franchising    object
# dtype: object
#      Rank  Restaurant  Location  Sales  YOY_Sales  Units  YOY_Units  \
# ...

# %%
df = np.genfromtxt(uri, delimiter= ',', skip_header= 1, usecols=(3,5), missing_values=0,dtype=float)
# Out:
# array([[nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
#        [nan, nan],
# ...

# %% [markdown]
# คำสั่ง df = np.genfromtxt(uri, delimiter=',', skip_header=1, usecols=(3,5), missing_values=0, dtype=float) ใช้สำหรับอ่านข้อมูลจากไฟล์ (หรือ URI) โดยเลือกเฉพาะคอลัมน์ที่ 3 และ 5 (นับจากศูนย์) และข้ามบรรทัดแรกที่มักเป็นหัวตาราง ข้อมูลจะถูกแยกตามเครื่องหมายคอมมา และแปลงเป็นชนิดตัวเลขทศนิยม (float) พร้อมทั้งกำหนดให้เลข 0 ในไฟล์ถือเป็นค่าที่หายไป (missing value) ซึ่งจะถูกแทนด้วย nan ในผลลัพธ์ที่ได้.

# %%
names = np.genfromtxt(uri,delimiter=',',skip_header=1, usecols=1,dtype=str)
segments = np.genfromtxt(uri,delimiter=',',skip_header=1, usecols=8, dtype=str)
print('data shape', df.shape)
print('Sample name', names[:5])
print('Sample segments',segments[:5])
# Out:
# data shape (50, 2)
# Sample name ['"Evergreens"' '"Clean Juice"' '"Slapfish"' '"Clean Eatz"' '"Pokeworks"']
# Sample segments ['1150' '560' '1370' '685' '1210']

# %%
total_sales = np.sum(df[:,0])
total_units = np.sum(df[:,1])
